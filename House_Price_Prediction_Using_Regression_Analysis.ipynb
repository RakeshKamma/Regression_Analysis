# %% [markdown]
# #REGRESSION - A basic template to compare different Regression models

# %% [markdown]
# ##AIM - Given no of beds,square lot size and other attributes, our model predicts the price it can sell for.

# %% [markdown]
# ##Compared Models
# ##MLR - Multiple Linear Regression
# ##PR - Polynomial Regression
# ##SVR - Support Vector Machines
# ##DT - Decision Trees
# ##RFR - Random Forest Regressor
# ##ANN - Artificial Neural Network
# ##XBG - XG Boost
# ##CB - Cat Boost

# %% [markdown]
# ##Importing libraries

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ##Loading pre-processed Dataset

# %%
dataset = pd.read_csv('/content/analytical_base_table_real_estate.csv')
X = dataset.iloc[:, 1:].values
y = dataset.iloc[:, 0].values
y = y.reshape(len(y),1)

# %% [markdown]
# ##Checking for null values

# %%
dataset.isnull().sum()
# Out:
# tx_price                                       0
# beds                                           0
# baths                                          0
# sqft                                           0
# lot_size                                       0
# restaurants                                    0
# groceries                                      0
# cafes                                          0
# shopping                                       0
# arts_entertainment                             0
# beauty_spas                                    0
# active_life                                    0
# median_age                                     0
# married                                        0
# college_grad                                   0
# median_school                                  0
# num_schools                                    0
# two_and_two                                    0
# old_properties                                 0
# tax_and_insurance                              0
# during_recession                               0
# property_age                                   0
# school_score                                   0
# exterior_walls_Brick                           0
# exterior_walls_Brick veneer                    0
# exterior_walls_Combination                     0
# exterior_walls_Metal                           0
# exterior_walls_Missing                         0
# exterior_walls_Other                           0
# exterior_walls_Siding (Alum/Vinyl)             0
# exterior_walls_Wood                            0
# roof_Asphalt                                   0
# roof_Composition Shingle                       0
# roof_Missing                                   0
# roof_Other                                     0
# roof_Shake Shingle                             0
# property_type_Apartment / Condo / Townhouse    0
# property_type_Single-Family                    0
# dtype: int64

# %%
print(X)
# Out:
# [[1.000e+00 1.000e+00 5.840e+02 ... 0.000e+00 1.000e+00 0.000e+00]
#  [1.000e+00 1.000e+00 6.120e+02 ... 0.000e+00 1.000e+00 0.000e+00]
#  [1.000e+00 1.000e+00 6.150e+02 ... 0.000e+00 1.000e+00 0.000e+00]
#  ...
#  [5.000e+00 6.000e+00 7.064e+03 ... 0.000e+00 0.000e+00 1.000e+00]
#  [5.000e+00 6.000e+00 7.500e+03 ... 0.000e+00 0.000e+00 1.000e+00]
#  [5.000e+00 6.000e+00 7.515e+03 ... 0.000e+00 0.000e+00 1.000e+00]]

# %%
print(y)
# Out:
# [[295850]
#  [216500]
#  [279900]
#  ...
#  [600000]
#  [759900]
#  [735000]]

# %% [markdown]
# ## Splitting dataset into Training and Testing Splits

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state = 1)

# %%
print(X_train)
# Out:
# [[1.000e+00 1.000e+00 7.810e+02 ... 0.000e+00 1.000e+00 0.000e+00]
#  [5.000e+00 3.000e+00 4.081e+03 ... 0.000e+00 0.000e+00 1.000e+00]
#  [3.000e+00 2.000e+00 1.360e+03 ... 0.000e+00 1.000e+00 0.000e+00]
#  ...
#  [5.000e+00 3.000e+00 3.384e+03 ... 0.000e+00 0.000e+00 1.000e+00]
#  [3.000e+00 2.000e+00 1.682e+03 ... 0.000e+00 0.000e+00 1.000e+00]
#  [3.000e+00 2.000e+00 2.766e+03 ... 0.000e+00 1.000e+00 0.000e+00]]

# %%
print(X_test)
# Out:
# [[4.000e+00 1.000e+00 1.365e+03 ... 0.000e+00 0.000e+00 1.000e+00]
#  [2.000e+00 2.000e+00 1.170e+03 ... 0.000e+00 1.000e+00 0.000e+00]
#  [4.000e+00 3.000e+00 3.513e+03 ... 0.000e+00 0.000e+00 1.000e+00]
#  ...
#  [3.000e+00 2.000e+00 1.404e+03 ... 0.000e+00 0.000e+00 1.000e+00]
#  [1.000e+00 1.000e+00 7.030e+02 ... 0.000e+00 1.000e+00 0.000e+00]
#  [4.000e+00 2.000e+00 2.394e+03 ... 0.000e+00 0.000e+00 1.000e+00]]

# %%
print(y_train)
# Out:
# [[345000]
#  [392500]
#  [250000]
#  ...
#  [345000]
#  [485000]
#  [392235]]

# %%
print(y_test)
# Out:
# [[325000]
#  [245000]
#  [483820]
#  [560000]
#  [450000]
#  [678000]
#  [469500]
#  [363700]
#  [614000]
#  [230000]
#  [471200]
#  [550000]
#  [433000]
#  [330000]
#  [560000]
#  [353140]
#  [385000]
#  [465000]
#  [520000]
#  [450000]
#  [647500]
#  [585000]
#  [630000]
#  [299000]
#  [785000]
#  [525000]
#  [255000]
#  [350000]
#  [420000]
#  [538430]
#  [279000]
#  [507500]
#  [585000]
#  [240000]
#  [642500]
#  [285000]
#  [310100]
#  [305000]
#  [715000]
#  [230000]
#  [425000]
#  [347644]
#  [462330]
#  [226000]
#  [653931]
#  [214900]
#  [475000]
#  [335000]
#  [422500]
#  [290000]
#  [485000]
#  [508000]
#  [218250]
#  [275000]
#  [650000]
#  [332815]
#  [459900]
#  [402500]
#  [279000]
#  [710000]
#  [395000]
#  [300000]
#  [342500]
#  [649000]
#  [306484]
#  [235000]
#  [347000]
#  [415000]
#  [375000]
#  [486990]
#  [269000]
#  [239000]
#  [560000]
#  [640000]
#  [421770]
#  [299000]
#  [355000]
#  [257000]
#  [340000]
#  [345000]
#  [778500]
#  [279000]
#  [305000]
#  [750000]
#  [510000]
#  [327500]
#  [495000]
#  [374900]
#  [215000]
#  [296000]
#  [313500]
#  [559900]
#  [595000]
#  [701900]
#  [377400]
#  [304000]
#  [390000]
#  [384406]
#  [489000]
#  [455900]
#  [439900]
#  [390000]
#  [480000]
#  [250000]
#  [336500]
#  [330000]
#  [215000]
#  [254000]
#  [570000]
#  [370000]
#  [246700]
#  [307500]
#  [594000]
#  [300000]
#  [202000]
#  [385500]
#  [329000]
#  [399900]
#  [279537]
#  [488000]
#  [580000]
#  [675000]
#  [310000]
#  [316500]
#  [675000]
#  [325000]
#  [717900]
#  [220000]
#  [502250]
#  [605000]
#  [673000]
#  [615000]
#  [407200]
#  [462604]
#  [452145]
#  [281900]
#  [399000]
#  [228000]
#  [350000]
#  [230000]
#  [279000]
#  [271900]
#  [450000]
#  [419000]
#  [730000]
#  [325000]
#  [558500]
#  [615000]
#  [389900]
#  [285810]
#  [303000]
#  [535000]
#  [746559]
#  [209900]
#  [485602]
#  [497650]
#  [434990]
#  [571600]
#  [451675]
#  [615000]
#  [418000]
#  [622500]
#  [388000]
#  [335000]
#  [410000]
#  [643000]
#  [765000]
#  [238000]
#  [426000]
#  [430000]
#  [364510]
#  [730000]
#  [231900]
#  [530000]
#  [346631]
#  [691331]
#  [574000]
#  [600000]
#  [200000]
#  [265000]
#  [359000]
#  [745000]
#  [790000]
#  [239000]
#  [200100]
#  [468000]
#  [446815]
#  [566700]
#  [215000]
#  [602504]
#  [450000]
#  [300000]
#  [485000]
#  [499000]
#  [782000]
#  [325344]
#  [210000]
#  [675000]
#  [295000]
#  [507175]
#  [305000]
#  [405000]
#  [385000]
#  [279000]
#  [450000]
#  [575000]
#  [280000]
#  [250000]
#  [457091]
#  [345000]
#  [440000]
#  [775000]
#  [515000]
#  [296790]
#  [417925]
#  [255000]
#  [401195]
#  [310000]
#  [409900]
#  [415000]
#  [440000]
#  [680000]
#  [400000]
#  [350000]
#  [215000]
#  [345000]
#  [281990]
#  [234000]
#  [255000]
#  [330000]
#  [649415]
#  [265000]
#  [284900]
#  [650000]
#  [384900]
#  [432000]
#  [425000]
#  [399500]
#  [785000]
#  [223000]
#  [575000]
#  [264900]
#  [375000]
#  [250000]
#  [526000]
#  [500000]
#  [661000]
#  [328000]
#  [238500]
#  [240800]
#  [630000]
#  [225000]
#  [513293]
#  [333000]
#  [399000]
#  [348500]
#  [260000]
#  [420000]
#  [200000]
#  [274500]
#  [418000]
#  [735000]
#  [793260]
#  [215000]
#  [326500]
#  [270000]
#  [680000]
#  [214000]
#  [588703]
#  [272000]
#  [416000]
#  [216500]
#  [650000]
#  [275000]
#  [408000]
#  [343000]
#  [517500]
#  [560000]
#  [225000]
#  [282500]
#  [250000]
#  [309990]
#  [544000]
#  [439000]
#  [640000]
#  [590000]
#  [235000]
#  [475000]
#  [342095]
#  [286900]
#  [375000]
#  [430000]
#  [740000]
#  [617000]
#  [482413]
#  [505000]
#  [465000]
#  [300367]
#  [443000]
#  [215000]
#  [728585]
#  [225000]
#  [336900]
#  [387500]
#  [470000]
#  [539900]
#  [590000]
#  [370000]
#  [212000]
#  [445000]
#  [440000]
#  [232200]
#  [575000]
#  [710000]
#  [268000]
#  [465000]
#  [358000]
#  [420000]
#  [370000]
#  [400000]
#  [285000]
#  [485000]
#  [525000]
#  [273050]
#  [468309]
#  [207000]
#  [400000]
#  [408900]
#  [235000]
#  [272500]
#  [229500]
#  [225000]
#  [265000]
#  [619000]
#  [305000]
#  [267579]
#  [340000]
#  [249950]
#  [390000]
#  [545000]
#  [377750]
#  [690000]
#  [279000]
#  [467000]
#  [401403]
#  [325000]
#  [265000]
#  [542450]
#  [334000]
#  [219900]
#  [242000]
#  [281000]
#  [225000]
#  [325000]
#  [790000]
#  [389990]
#  [297000]
#  [300000]
#  [416000]
#  [215000]
#  [275000]
#  [345000]
#  [420000]
#  [628000]
#  [345000]
#  [570000]
#  [500000]
#  [336873]
#  [379000]
#  [391000]
#  [304320]
#  [598000]
#  [580000]
#  [435000]
#  [560000]
#  [400000]
#  [280000]
#  [540000]
#  [429000]
#  [582499]
#  [488512]
#  [675000]
#  [340000]
#  [399900]
#  [428000]
#  [346080]
#  [525000]
#  [475000]
#  [610000]
#  [440000]
#  [250000]
#  [399900]
#  [655000]
#  [385000]
#  [417000]
#  [692914]
#  [211500]
#  [385000]
#  [250000]
#  [615000]
#  [355000]
#  [404816]
#  [226000]
#  [474000]
#  [430000]
#  [475000]
#  [385000]
#  [750000]
#  [273001]
#  [375000]
#  [375000]
#  [240000]
#  [295000]
#  [297000]
#  [285540]
#  [650000]
#  [278000]
#  [535000]
#  [451500]
#  [352000]
#  [412250]
#  [227000]
#  [345000]
#  [385000]
#  [709233]
#  [387000]
#  [394000]
#  [225000]
#  [350000]
#  [330000]
#  [499977]
#  [250000]
#  [615000]
#  [257600]
#  [489950]
#  [370000]
#  [295000]
#  [800000]
#  [607000]
#  [386000]
#  [200000]
#  [250000]
#  [581710]
#  [525000]
#  [290000]
#  [319500]
#  [310000]
#  [490000]
#  [500000]
#  [280000]
#  [589000]
#  [320000]
#  [400000]
#  [525000]
#  [299000]
#  [465000]
#  [626934]
#  [425000]
#  [770000]
#  [271500]
#  [216500]
#  [640000]
#  [625000]
#  [399000]
#  [240000]
#  [269900]]

# %% [markdown]
# ## Apply Scaling to our features

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)


sc1 = StandardScaler()
y_train = sc1.fit_transform(y_train)
y_test = sc1.transform(y_test)

# %% [markdown]
# ## Applying Dimensionality Reduction with Kernel PCA(Feature Reduction)

# %%
from sklearn.decomposition import KernelPCA
kpca = KernelPCA(n_components = 2, kernel = 'rbf')
X_train = kpca.fit_transform(X_train)
X_test = kpca.transform(X_test)

# %% [markdown]
# #Models

# %% [markdown]
# ##Multi Linear Regression

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import LinearRegression

# Create a LinearRegression model
MLR_regressor = LinearRegression()

# Define the parameter grid
param_grid = {
    'fit_intercept': [True, False]
}

# Create the GridSearchCV object
grid_search = GridSearchCV(MLR_regressor, param_grid, cv=5)  # cv is the number of cross-validation folds

# Fit the model to the data
grid_search.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=LinearRegression(),
#              param_grid={'fit_intercept': [True, False]})

# %%
best_model = grid_search.best_estimator_
# Use the best model to make predictions
y_pred = best_model.predict(X_test)

# y_pred now contains the predicted values for the test data

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# Calculate the MSE (Mean Squared Error)
MLR_mse = mean_squared_error(y_test, y_pred)

# Calculate the RMSE (Root Mean Squared Error)
MLR_rmse = np.sqrt(MLR_mse)

# Calculate the MAE (Mean Absolute Error)
MLR_mae = mean_absolute_error(y_test, y_pred)

# Calculate the R-squared (R²) score
MLR_r2 = r2_score(y_test, y_pred)

# Print the metrics
print("Root Mean Squared Error (RMSE):", MLR_rmse)
print("Mean Absolute Error (MAE):", MLR_mae)
print("R-squared (R²):", MLR_r2)
# Out:
# Root Mean Squared Error (RMSE): 0.8940075912139515
# Mean Absolute Error (MAE): 0.7360220386880357
# R-squared (R²): 0.18890075883045587

# %% [markdown]
# ##Polynomial Regression

# %%
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import Ridge  # You can choose Ridge or Lasso
from sklearn.pipeline import make_pipeline

# Create a Polynomial Regression model with Ridge regularization
poly_reg = PolynomialFeatures(degree=2)
poly_regressor = Ridge()

# Create a pipeline for Polynomial Regression with Ridge regularization
model = make_pipeline(poly_reg, poly_regressor)

# Define the parameter grid
param_grid = {
    'polynomialfeatures__degree': [2, 3, 4],  # Try different polynomial degrees
    'ridge__alpha': [0.01, 0.1, 1.0]  # Try different alpha values for Ridge
}

# Create the GridSearchCV object
grid_search = GridSearchCV(model, param_grid, cv=5)  # cv is the number of cross-validation folds

# Fit the model to the data
grid_search.fit(X_train, y_train)

# Print the best hyperparameters
best_params = grid_search.best_params_
print("Best Hyperparameters:", best_params)

# Get the best estimator
best_model = grid_search.best_estimator_

# You can use best_model for predictions
# Out:
# Best Hyperparameters: {'polynomialfeatures__degree': 4, 'ridge__alpha': 0.01}

# %%
y_pred=best_model.predict(X_test)

# %%
# Calculate the MSE (Mean Squared Error)
PR_mse = mean_squared_error(y_test, y_pred)

# Calculate the RMSE (Root Mean Squared Error)
PR_rmse = np.sqrt(MLR_mse)

# Calculate the MAE (Mean Absolute Error)
PR_mae = mean_absolute_error(y_test, y_pred)

# Calculate the R-squared (R²) score
PR_r2 = r2_score(y_test, y_pred)

# Print the metrics
print("Root Mean Squared Error (RMSE):", PR_rmse)
print("Mean Absolute Error (MAE):", PR_mae)
print("R-squared (R²):", PR_r2)
# Out:
# Root Mean Squared Error (RMSE): 0.8940075912139515
# Mean Absolute Error (MAE): 0.707641625475943
# R-squared (R²): 0.22182494187124424

# %%
np.set_printoptions(precision=2)
print(np.concatenate((y_pred.reshape(len(y_pred),1), y_test.reshape(len(y_test),1)),1))
# Out:
# [[-3.62e-01 -6.55e-01]
#  [-2.03e-01 -1.18e+00]
#  [ 3.31e-01  3.90e-01]
#  [ 1.73e-01  8.91e-01]
#  [ 5.94e-02  1.68e-01]
#  [ 5.45e-01  1.67e+00]
#  [ 3.99e-03  2.96e-01]
#  [-2.13e-01 -4.00e-01]
#  [ 4.29e-01  1.25e+00]
#  [-6.38e-01 -1.28e+00]
#  [ 1.05e+00  3.07e-01]
#  [ 8.89e-01  8.26e-01]
#  [ 4.72e-01  5.57e-02]
#  [-7.08e-01 -6.22e-01]
#  [ 3.59e-01  8.91e-01]
#  [-2.90e-01 -4.70e-01]
#  [-4.12e-01 -2.60e-01]
#  [ 5.72e-01  2.66e-01]
#  [ 1.98e-01  6.28e-01]
#  [-3.99e-01  1.68e-01]
#  [-7.68e-02  1.47e+00]
#  [-7.11e-02  1.06e+00]
#  [-1.16e-01  1.35e+00]
#  [ 1.44e-03 -8.26e-01]
#  [ 7.76e-01  2.37e+00]
#  [-2.28e-01  6.61e-01]
#  [-3.86e-01 -1.12e+00]
#  [-5.34e-01 -4.90e-01]
#  [-2.25e-02 -2.99e-02]
#  [-1.53e-01  7.49e-01]
#  [ 6.59e-01 -9.58e-01]
#  [ 1.11e+00  5.46e-01]
#  [ 5.57e-01  1.06e+00]
#  [-9.18e-02 -1.21e+00]
#  [ 5.72e-01  1.43e+00]
#  [-9.08e-02 -9.18e-01]
#  [-1.38e-01 -7.53e-01]
#  [-5.48e-01 -7.87e-01]
#  [ 9.05e-01  1.91e+00]
#  [-2.72e-01 -1.28e+00]
#  [-5.98e-01  3.04e-03]
#  [-2.72e-01 -5.06e-01]
#  [-5.96e-01  2.49e-01]
#  [-8.91e-01 -1.31e+00]
#  [-7.93e-01  1.51e+00]
#  [-3.28e-01 -1.38e+00]
#  [-9.71e-02  3.32e-01]
#  [-8.37e-01 -5.89e-01]
#  [-3.08e-01 -1.34e-02]
#  [ 1.37e-01 -8.85e-01]
#  [-3.97e-01  3.98e-01]
#  [ 7.79e-01  5.49e-01]
#  [ 1.21e-01 -1.36e+00]
#  [ 1.51e-01 -9.84e-01]
#  [ 8.30e-01  1.48e+00]
#  [ 1.16e-01 -6.04e-01]
#  [-2.31e-01  2.33e-01]
#  [-3.50e-01 -1.45e-01]
#  [ 4.70e-01 -9.58e-01]
#  [ 9.60e-02  1.88e+00]
#  [-1.88e-01 -1.94e-01]
#  [-2.54e-01 -8.19e-01]
#  [-8.35e-01 -5.40e-01]
#  [-4.11e-02  1.48e+00]
#  [-2.48e-01 -7.77e-01]
#  [ 1.94e-01 -1.25e+00]
#  [-5.13e-01 -5.10e-01]
#  [-2.07e-01 -6.28e-02]
#  [-1.38e-01 -3.26e-01]
#  [-8.43e-01  4.11e-01]
#  [-3.63e-01 -1.02e+00]
#  [-6.50e-01 -1.22e+00]
#  [ 3.69e-01  8.91e-01]
#  [ 4.25e-01  1.42e+00]
#  [ 4.11e-01 -1.82e-02]
#  [-3.94e-01 -8.26e-01]
#  [ 7.03e-01 -4.58e-01]
#  [-1.95e-01 -1.10e+00]
#  [-2.70e-01 -5.56e-01]
#  [ 3.07e-02 -5.23e-01]
#  [ 2.04e-01  2.33e+00]
#  [-7.71e-01 -9.58e-01]
#  [-1.06e-01 -7.87e-01]
#  [ 5.41e-01  2.14e+00]
#  [ 2.58e-01  5.62e-01]
#  [-5.59e-01 -6.38e-01]
#  [-3.21e-01  4.64e-01]
#  [-8.36e-01 -3.27e-01]
#  [-7.00e-01 -1.38e+00]
#  [-5.72e-01 -8.46e-01]
#  [-8.23e-01 -7.31e-01]
#  [ 1.99e-01  8.91e-01]
#  [-3.81e-01  1.12e+00]
#  [ 5.14e-01  1.83e+00]
#  [-6.35e-01 -3.10e-01]
#  [ 1.67e-01 -7.93e-01]
#  [-3.50e-01 -2.27e-01]
#  [-2.68e-02 -2.64e-01]
#  [-1.10e-01  4.24e-01]
#  [-4.15e-01  2.06e-01]
#  [-4.32e-01  1.01e-01]
#  [-1.66e-01 -2.27e-01]
#  [ 8.40e-02  3.65e-01]
#  [-6.64e-01 -1.15e+00]
#  [ 6.51e-01 -5.79e-01]
#  [-3.16e-01 -6.22e-01]
#  [-9.04e-01 -1.38e+00]
#  [-6.02e-01 -1.12e+00]
#  [ 4.82e-02  9.57e-01]
#  [ 7.84e-01 -3.59e-01]
#  [-7.11e-01 -1.17e+00]
#  [-7.71e-01 -7.70e-01]
#  [ 2.63e-01  1.12e+00]
#  [ 3.43e-01 -8.19e-01]
#  [-2.44e-01 -1.46e+00]
#  [-2.71e-01 -2.57e-01]
#  [ 1.35e-01 -6.29e-01]
#  [-4.74e-01 -1.62e-01]
#  [-5.48e-03 -9.54e-01]
#  [ 2.96e-01  4.18e-01]
#  [ 4.63e-02  1.02e+00]
#  [ 2.95e-01  1.65e+00]
#  [ 5.65e-02 -7.54e-01]
#  [ 9.91e-02 -7.11e-01]
#  [ 2.23e-01  1.65e+00]
#  [ 3.69e-02 -6.55e-01]
#  [ 3.38e-01  1.93e+00]
#  [-8.38e-03 -1.35e+00]
#  [ 1.85e-01  5.11e-01]
#  [-5.98e-01  1.19e+00]
#  [ 2.99e-01  1.63e+00]
#  [ 7.97e-01  1.25e+00]
#  [-9.12e-02 -1.14e-01]
#  [-4.71e-01  2.50e-01]
#  [-3.26e-01  1.82e-01]
#  [-1.04e+00 -9.39e-01]
#  [-4.14e-01 -1.68e-01]
#  [-4.34e-01 -1.29e+00]
#  [ 1.08e+00 -4.90e-01]
#  [-5.25e-01 -1.28e+00]
#  [-4.81e-01 -9.58e-01]
#  [-4.15e-01 -1.00e+00]
#  [-1.51e-01  1.68e-01]
#  [-4.34e-02 -3.64e-02]
#  [ 8.14e-01  2.01e+00]
#  [-6.45e-01 -6.55e-01]
#  [ 7.18e-01  8.81e-01]
#  [ 1.19e-01  1.25e+00]
#  [-2.85e-01 -2.28e-01]
#  [-4.39e-01 -9.13e-01]
#  [ 6.29e-01 -8.00e-01]
#  [ 5.67e-01  7.27e-01]
#  [-9.15e-02  2.12e+00]
#  [-2.34e-01 -1.41e+00]
#  [-7.29e-01  4.02e-01]
#  [-7.17e-02  4.81e-01]
#  [ 3.71e-01  6.88e-02]
#  [ 6.40e-01  9.68e-01]
#  [-2.92e-01  1.79e-01]
#  [ 8.72e-01  1.25e+00]
#  [ 3.72e-01 -4.30e-02]
#  [-5.26e-01  1.30e+00]
#  [ 3.57e-01 -2.40e-01]
#  [-7.80e-01 -5.89e-01]
#  [-7.80e-01 -9.57e-02]
#  [ 3.65e-01  1.44e+00]
#  [ 1.23e+00  2.24e+00]
#  [ 8.58e-01 -1.23e+00]
#  [-1.25e-02  9.62e-03]
#  [ 4.66e-01  3.59e-02]
#  [ 1.46e-01 -3.95e-01]
#  [ 9.80e-01  2.01e+00]
#  [-8.87e-01 -1.27e+00]
#  [ 2.55e-01  6.94e-01]
#  [-8.58e-01 -5.13e-01]
#  [ 1.02e+00  1.76e+00]
#  [ 3.39e-01  9.83e-01]
#  [ 8.19e-01  1.15e+00]
#  [-4.28e-01 -1.48e+00]
#  [-7.05e-01 -1.05e+00]
#  [-5.26e-01 -4.31e-01]
#  [ 4.04e-01  2.11e+00]
#  [ 5.14e-01  2.40e+00]
#  [-4.22e-01 -1.22e+00]
#  [ 1.14e-01 -1.48e+00]
#  [-3.73e-01  2.86e-01]
#  [ 2.04e-01  1.47e-01]
#  [ 4.53e-02  9.35e-01]
#  [ 6.30e-01 -1.38e+00]
#  [ 2.86e-01  1.17e+00]
#  [-2.19e-02  1.68e-01]
#  [-8.01e-01 -8.19e-01]
#  [-7.69e-02  3.98e-01]
#  [ 4.08e-01  4.90e-01]
#  [ 5.39e-01  2.35e+00]
#  [-3.97e-01 -6.53e-01]
#  [-7.44e-01 -1.41e+00]
#  [ 6.51e-01  1.65e+00]
#  [-3.63e-01 -8.52e-01]
#  [ 8.70e-01  5.44e-01]
#  [-5.26e-01 -7.87e-01]
#  [-1.87e-01 -1.29e-01]
#  [-8.24e-01 -2.60e-01]
#  [-3.44e-01 -9.58e-01]
#  [-7.65e-02  1.68e-01]
#  [ 5.48e-01  9.90e-01]
#  [-2.05e-01 -9.51e-01]
#  [-1.98e-01 -1.15e+00]
#  [-5.63e-02  2.14e-01]
#  [ 1.20e-01 -5.23e-01]
#  [-4.24e-01  1.02e-01]
#  [ 5.34e-01  2.31e+00]
#  [ 3.63e-01  5.95e-01]
#  [ 6.69e-01 -8.41e-01]
#  [ 7.23e-01 -4.35e-02]
#  [-2.40e-01 -1.12e+00]
#  [ 3.68e-03 -1.54e-01]
#  [ 7.69e-01 -7.54e-01]
#  [ 2.93e-01 -9.63e-02]
#  [-4.42e-01 -6.28e-02]
#  [ 2.87e-01  1.02e-01]
#  [-5.35e-01  1.68e+00]
#  [ 5.70e-01 -1.61e-01]
#  [-8.51e-02 -4.90e-01]
#  [-6.39e-01 -1.38e+00]
#  [-8.44e-01 -5.23e-01]
#  [ 3.14e-02 -9.38e-01]
#  [ 3.45e-01 -1.25e+00]
#  [ 4.65e-01 -1.12e+00]
#  [-4.17e-01 -6.22e-01]
#  [ 1.03e+00  1.48e+00]
#  [-4.42e-01 -1.05e+00]
#  [ 1.17e-01 -9.19e-01]
#  [ 6.89e-01  1.48e+00]
#  [-6.40e-01 -2.61e-01]
#  [ 6.67e-01  4.91e-02]
#  [-2.84e-01  3.04e-03]
#  [-1.92e-01 -1.65e-01]
#  [-3.20e-01  2.37e+00]
#  [ 2.28e-01 -1.33e+00]
#  [ 7.29e-01  9.90e-01]
#  [-3.23e-01 -1.05e+00]
#  [-3.78e-01 -3.26e-01]
#  [-5.69e-01 -1.15e+00]
#  [-6.91e-01  6.68e-01]
#  [ 6.95e-01  4.97e-01]
#  [ 2.35e-01  1.56e+00]
#  [-7.20e-01 -6.35e-01]
#  [-1.95e-02 -1.22e+00]
#  [ 3.62e-01 -1.21e+00]
#  [ 5.31e-01  1.35e+00]
#  [-5.86e-01 -1.31e+00]
#  [ 2.60e-01  5.84e-01]
#  [-4.46e-01 -6.02e-01]
#  [ 2.88e-01 -1.68e-01]
#  [-5.62e-01 -5.00e-01]
#  [-6.17e-02 -1.08e+00]
#  [ 6.45e-01 -2.99e-02]
#  [-4.07e-01 -1.48e+00]
#  [-5.56e-02 -9.87e-01]
#  [-5.92e-02 -4.30e-02]
#  [ 1.04e+00  2.04e+00]
#  [ 3.10e-01  2.43e+00]
#  [-8.20e-01 -1.38e+00]
#  [ 5.02e-01 -6.45e-01]
#  [-8.02e-01 -1.02e+00]
#  [ 6.32e-01  1.68e+00]
#  [-3.83e-01 -1.39e+00]
#  [ 8.22e-01  1.08e+00]
#  [ 8.12e-03 -1.00e+00]
#  [-4.48e-01 -5.62e-02]
#  [-8.76e-01 -1.37e+00]
#  [ 1.01e+00  1.48e+00]
#  [-5.40e-01 -9.84e-01]
#  [-5.59e-01 -1.09e-01]
#  [-1.41e-01 -5.37e-01]
#  [-4.02e-01  6.12e-01]
#  [-2.33e-01  8.91e-01]
#  [-4.11e-01 -1.31e+00]
#  [-3.62e-01 -9.35e-01]
#  [-3.39e-02 -1.15e+00]
#  [-3.16e-01 -7.54e-01]
#  [ 1.15e-01  7.86e-01]
#  [ 4.13e-01  9.52e-02]
#  [-2.91e-01  1.42e+00]
#  [ 4.03e-01  1.09e+00]
#  [-5.77e-01 -1.25e+00]
#  [ 5.34e-01  3.32e-01]
#  [ 2.89e-01 -5.42e-01]
#  [-9.04e-01 -9.06e-01]
#  [ 2.69e-01 -3.26e-01]
#  [-1.42e-01  3.59e-02]
#  [ 1.64e-01  2.08e+00]
#  [ 8.31e-01  1.27e+00]
#  [-4.98e-01  3.81e-01]
#  [-7.93e-01  5.29e-01]
#  [ 5.75e-01  2.66e-01]
#  [ 1.18e-01 -8.17e-01]
#  [ 6.05e-01  1.21e-01]
#  [ 4.25e-01 -1.38e+00]
#  [ 1.02e+00  2.00e+00]
#  [ 6.03e-01 -1.31e+00]
#  [-7.07e-01 -5.77e-01]
#  [ 4.53e-01 -2.44e-01]
#  [-3.89e-01  2.99e-01]
#  [-7.61e-01  7.59e-01]
#  [ 1.79e-01  1.09e+00]
#  [-2.03e-01 -3.59e-01]
#  [ 1.13e-01 -1.40e+00]
#  [-2.35e-01  1.35e-01]
#  [-1.44e-01  1.02e-01]
#  [ 5.45e-02 -1.27e+00]
#  [ 3.99e-01  9.90e-01]
#  [ 9.46e-01  1.88e+00]
#  [ 3.37e-02 -1.03e+00]
#  [ 1.03e-02  2.66e-01]
#  [-5.33e-01 -4.38e-01]
#  [ 5.45e-01 -2.99e-02]
#  [ 9.68e-03 -3.59e-01]
#  [-2.52e-01 -1.61e-01]
#  [-7.66e-01 -9.18e-01]
#  [-2.64e-01  3.98e-01]
#  [ 8.44e-02  6.61e-01]
#  [-2.61e-01 -9.97e-01]
#  [ 6.51e-01  2.88e-01]
#  [ 2.97e-01 -1.43e+00]
#  [ 1.36e-02 -1.61e-01]
#  [ 7.32e-01 -1.03e-01]
#  [-6.64e-01 -1.25e+00]
#  [ 1.18e-02 -1.00e+00]
#  [-9.16e-02 -1.28e+00]
#  [-4.38e-01 -1.31e+00]
#  [ 9.27e-02 -1.05e+00]
#  [ 2.01e-01  1.28e+00]
#  [-6.88e-01 -7.87e-01]
#  [ 3.16e-01 -1.03e+00]
#  [-5.46e-01 -5.56e-01]
#  [-4.17e-01 -1.15e+00]
#  [-6.25e-02 -2.27e-01]
#  [-7.84e-02  7.93e-01]
#  [-2.56e-01 -3.08e-01]
#  [ 8.95e-01  1.75e+00]
#  [ 9.47e-02 -9.58e-01]
#  [-7.53e-01  2.79e-01]
#  [ 3.49e-01 -1.52e-01]
#  [-2.92e-01 -6.55e-01]
#  [ 8.20e-01 -1.05e+00]
#  [ 1.68e-01  7.76e-01]
#  [-3.92e-02 -5.96e-01]
#  [ 1.16e-01 -1.35e+00]
#  [-8.11e-01 -1.20e+00]
#  [ 5.31e-03 -9.44e-01]
#  [-1.79e-01 -1.31e+00]
#  [-4.17e-01 -6.55e-01]
#  [ 5.90e-01  2.40e+00]
#  [ 7.95e-02 -2.27e-01]
#  [-7.23e-01 -8.39e-01]
#  [ 2.47e-01 -8.19e-01]
#  [-5.54e-01 -5.62e-02]
#  [-8.30e-02 -1.38e+00]
#  [ 6.83e-01 -9.84e-01]
#  [-3.90e-01 -5.23e-01]
#  [-1.56e-01 -2.99e-02]
#  [ 4.58e-01  1.34e+00]
#  [ 2.98e-02 -5.23e-01]
#  [ 2.08e-01  9.57e-01]
#  [ 2.05e-01  4.97e-01]
#  [-3.21e-01 -5.77e-01]
#  [-7.50e-01 -3.00e-01]
#  [-2.26e-01 -2.21e-01]
#  [-3.53e-01 -7.91e-01]
#  [ 6.14e-01  1.14e+00]
#  [ 5.10e-02  1.02e+00]
#  [ 4.97e-01  6.88e-02]
#  [ 3.46e-02  8.91e-01]
#  [ 3.84e-01 -1.61e-01]
#  [-5.84e-01 -9.51e-01]
#  [ 9.87e-02  7.60e-01]
#  [-3.22e-01  2.94e-02]
#  [ 2.90e-01  1.04e+00]
#  [ 4.78e-01  4.21e-01]
#  [ 3.06e-01  1.65e+00]
#  [-6.42e-01 -5.56e-01]
#  [-2.55e-01 -1.62e-01]
#  [-5.31e-01  2.28e-02]
#  [ 3.21e-01 -5.16e-01]
#  [ 3.86e-02  6.61e-01]
#  [-5.05e-01  3.32e-01]
#  [ 2.23e-01  1.22e+00]
#  [ 3.67e-01  1.02e-01]
#  [-4.27e-01 -1.15e+00]
#  [-3.14e-01 -1.62e-01]
#  [ 5.69e-01  1.52e+00]
#  [ 9.28e-02 -2.60e-01]
#  [-4.17e-01 -4.96e-02]
#  [ 5.20e-01  1.77e+00]
#  [-1.45e-01 -1.40e+00]
#  [-1.69e-01 -2.60e-01]
#  [-7.26e-01 -1.15e+00]
#  [-4.83e-01  1.25e+00]
#  [ 2.33e-01 -4.58e-01]
#  [ 5.40e-01 -1.30e-01]
#  [ 3.88e-02 -1.31e+00]
#  [-2.08e-01  3.25e-01]
#  [ 2.37e-02  3.59e-02]
#  [ 2.76e-01  3.32e-01]
#  [-4.45e-01 -2.60e-01]
#  [ 4.11e-01  2.14e+00]
#  [-3.56e-02 -9.97e-01]
#  [ 1.66e-01 -3.26e-01]
#  [ 5.72e-02 -3.26e-01]
#  [-2.84e-01 -1.21e+00]
#  [-8.25e-01 -8.52e-01]
#  [-7.56e-01 -8.39e-01]
#  [-2.44e-01 -9.15e-01]
#  [ 2.76e-01  1.48e+00]
#  [-8.30e-01 -9.64e-01]
#  [ 3.63e-01  7.27e-01]
#  [-4.03e-01  1.77e-01]
#  [ 6.93e-01 -4.77e-01]
#  [ 4.49e-01 -8.09e-02]
#  [-3.43e-01 -1.30e+00]
#  [-7.05e-01 -5.23e-01]
#  [-4.04e-01 -2.60e-01]
#  [ 1.10e+00  1.87e+00]
#  [-6.02e-01 -2.47e-01]
#  [ 2.29e-01 -2.01e-01]
#  [-1.70e-01 -1.31e+00]
#  [-1.66e-01 -4.90e-01]
#  [-2.70e-01 -6.22e-01]
#  [ 3.81e-01  4.96e-01]
#  [ 4.87e-02 -1.15e+00]
#  [ 2.19e-01  1.25e+00]
#  [-2.97e-01 -1.10e+00]
#  [-2.57e-01  4.30e-01]
#  [-3.36e-01 -3.59e-01]
#  [-6.02e-01 -8.52e-01]
#  [ 5.20e-01  2.47e+00]
#  [ 1.92e-01  1.20e+00]
#  [ 3.48e-01 -2.54e-01]
#  [ 5.38e-01 -1.48e+00]
#  [-6.30e-01 -1.15e+00]
#  [ 9.74e-02  1.03e+00]
#  [ 5.19e-01  6.61e-01]
#  [-2.78e-02 -8.85e-01]
#  [-6.69e-01 -6.91e-01]
#  [ 3.86e-01 -7.54e-01]
#  [ 5.50e-01  4.31e-01]
#  [-1.77e-01  4.97e-01]
#  [-5.49e-01 -9.51e-01]
#  [ 6.00e-01  1.08e+00]
#  [ 8.46e-02 -6.88e-01]
#  [ 2.61e-01 -1.61e-01]
#  [ 6.90e-01  6.61e-01]
#  [-1.68e-01 -8.26e-01]
#  [-3.06e-01  2.66e-01]
#  [-3.64e-01  1.33e+00]
#  [ 4.76e-01  3.04e-03]
#  [ 2.51e-01  2.27e+00]
#  [ 2.40e-01 -1.01e+00]
#  [ 2.37e-01 -1.37e+00]
#  [ 4.09e-01  1.42e+00]
#  [ 3.24e-01  1.32e+00]
#  [ 1.10e-01 -1.68e-01]
#  [-6.53e-01 -1.21e+00]
#  [ 3.09e-01 -1.02e+00]]

# %% [markdown]
# ##Support vector machine

# %%
from sklearn.svm import SVR  # For Support Vector Regression, or you can use SVC for classification

# Create an SVM model
svm_regressor = SVR()  # For classification, you can use SVC()

# Define the parameter grid
param_grid = {
    'C': [0.1, 1, 10],          # Regularization parameter
    'kernel': ['linear', 'rbf'],  # Kernel type: linear or radial basis function (RBF)
    'gamma': [0.1, 1, 10]        # Kernel coefficient for 'rbf'
}

# Create the GridSearchCV object
grid_search = GridSearchCV(svm_regressor, param_grid, cv=5)  # cv is the number of cross-validation folds

# Fit the model to the data
grid_search.fit(X_train, y_train)  # X_train and y_train are your training data

# Print the best hyperparameters
best_params = grid_search.best_params_
print("Best Hyperparameters:", best_params)

# Get the best estimator
best_model = grid_search.best_estimator_

# You can use best_model for predictions
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Best Hyperparameters: {'C': 1, 'gamma': 10, 'kernel': 'rbf'}
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
y_pred = best_model.predict(X_test)

# %%
# Calculate the MSE (Mean Squared Error)
SVR_mse = mean_squared_error(y_test, y_pred)

# Calculate the RMSE (Root Mean Squared Error)
SVR_rmse = np.sqrt(MLR_mse)

# Calculate the MAE (Mean Absolute Error)
SVR_mae = mean_absolute_error(y_test, y_pred)

# Calculate the R-squared (R²) score
SVR_r2 = r2_score(y_test, y_pred)

# Print the metrics
print("Root Mean Squared Error (RMSE):", SVR_rmse)
print("Mean Absolute Error (MAE):", SVR_mae)
print("R-squared (R²):", SVR_r2)
# Out:
# Root Mean Squared Error (RMSE): 0.8940075912139515
# Mean Absolute Error (MAE): 0.6980711850119169
# R-squared (R²): 0.22514981173301263

# %% [markdown]
# ##Decision Trees

# %%
from sklearn.ensemble import RandomForestRegressor

# Create a RandomForestRegressor model
rf_regressor = RandomForestRegressor()

# Define the parameter grid for Random Forest
param_grid = {
    'n_estimators': [100, 200, 300],  # Number of trees in the forest
    'max_depth': [None, 10, 20],  # Maximum depth of each tree
    'min_samples_split': [2, 5, 10],  # Minimum samples required to split a node
    'min_samples_leaf': [1, 2, 4]  # Minimum samples required for a leaf node
}

# Create the GridSearchCV object
grid_search = GridSearchCV(rf_regressor, param_grid, cv=5)

# Fit the model to the data
grid_search.fit(X_train, y_train)

# Print the best hyperparameters
best_params = grid_search.best_params_
print("Best Hyperparameters:", best_params)

# Get the best estimator
best_model = grid_search.best_estimator_

# You can use best_model for predictions
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# ...
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_search.py:909: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self.best_estimator_.fit(X, y, **fit_params)
# Best Hyperparameters: {'max_depth': 10, 'min_samples_leaf': 2, 'min_samples_split': 10, 'n_estimators': 200}

# %%
y_pred = best_model.predict(X_test)

# %%
# Calculate the MSE (Mean Squared Error)
DT_mse = mean_squared_error(y_test, y_pred)

# Calculate the RMSE (Root Mean Squared Error)
DT_rmse = np.sqrt(MLR_mse)

# Calculate the MAE (Mean Absolute Error)
DT_mae = mean_absolute_error(y_test, y_pred)

# Calculate the R-squared (R²) score
DT_r2 = r2_score(y_test, y_pred)

# Print the metrics
print("Root Mean Squared Error (RMSE):", DT_rmse)
print("Mean Absolute Error (MAE):", DT_mae)
print("R-squared (R²):", DT_r2)
# Out:
# Root Mean Squared Error (RMSE): 0.8940075912139515
# Mean Absolute Error (MAE): 0.7099355911485635
# R-squared (R²): 0.19348769656098985

# %% [markdown]
# ##Random Forest

# %%
from sklearn.ensemble import RandomForestRegressor  # For regression tasks, or use RandomForestClassifier for classification

# Create a Random Forest model
rf_regressor = RandomForestRegressor()  # For classification, use RandomForestClassifier()

# Define the parameter grid
param_grid = {
    'n_estimators': [100, 200, 300],  # Number of trees in the forest
    'max_depth': [None, 10, 20],  # Maximum depth of each tree
    'min_samples_split': [2, 5, 10],  # Minimum samples required to split a node
    'min_samples_leaf': [1, 2, 4]  # Minimum samples required for a leaf node
}

# Create the GridSearchCV object
grid_search = GridSearchCV(rf_regressor, param_grid, cv=5)  # cv is the number of cross-validation folds

# Fit the model to the data
grid_search.fit(X_train, y_train)  # X_train and y_train are your training data

# Print the best hyperparameters
best_params = grid_search.best_params_
print("Best Hyperparameters:", best_params)

# Get the best estimator
best_model = grid_search.best_estimator_

# You can use best_model for predictions
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# ...
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# Best Hyperparameters: {'max_depth': 10, 'min_samples_leaf': 4, 'min_samples_split': 10, 'n_estimators': 100}
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_search.py:909: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self.best_estimator_.fit(X, y, **fit_params)

# %%
y_pred = best_model.predict(X_test)

# %%
# Calculate the MSE (Mean Squared Error)
RFR_mse = mean_squared_error(y_test, y_pred)

# Calculate the RMSE (Root Mean Squared Error)
RFR_rmse = np.sqrt(MLR_mse)

# Calculate the MAE (Mean Absolute Error)
RFR_mae = mean_absolute_error(y_test, y_pred)

# Calculate the R-squared (R²) score
RFR_r2 = r2_score(y_test, y_pred)

# Print the metrics
print("Root Mean Squared Error (RMSE):", RFR_rmse)
print("Mean Absolute Error (MAE):", RFR_mae)
print("R-squared (R²):", RFR_r2)
# Out:
# Root Mean Squared Error (RMSE): 0.8940075912139515
# Mean Absolute Error (MAE): 0.7092531207901281
# R-squared (R²): 0.1912195618702065

# %% [markdown]
# ##Artificial Neural Networks

# %%
import tensorflow as tf

# %%
ann = tf.keras.models.Sequential()

# %%
ann.add(tf.keras.layers.Dense(units=6, activation='relu'))

# %%
ann.add(tf.keras.layers.Dense(units=6, activation='relu'))

# %%
ann.add(tf.keras.layers.Dense(units=6, activation='relu'))

# %%
ann.add(tf.keras.layers.Dense(units=1, activation='sigmoid'))

# %%
ann.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

# %%
ann.fit(X_train, y_train, batch_size = 2, epochs = 100)
# Out:
# Epoch 1/100
# 699/699 [==============================] - 2s 1ms/step - loss: 0.0997 - accuracy: 0.0000e+00
# Epoch 2/100
# 699/699 [==============================] - 1s 1ms/step - loss: -2.7534 - accuracy: 0.0000e+00
# Epoch 3/100
# 699/699 [==============================] - 1s 1ms/step - loss: -20.1348 - accuracy: 0.0000e+00
# Epoch 4/100
# 699/699 [==============================] - 1s 1ms/step - loss: -77.3339 - accuracy: 0.0000e+00
# Epoch 5/100
# 699/699 [==============================] - 1s 1ms/step - loss: -199.8286 - accuracy: 0.0000e+00
# Epoch 6/100
# 699/699 [==============================] - 1s 1ms/step - loss: -412.4402 - accuracy: 0.0000e+00
# Epoch 7/100
# 699/699 [==============================] - 1s 1ms/step - loss: -738.2405 - accuracy: 0.0000e+00
# Epoch 8/100
# 699/699 [==============================] - 1s 1ms/step - loss: -1207.8889 - accuracy: 0.0000e+00
# Epoch 9/100
# 699/699 [==============================] - 1s 1ms/step - loss: -1845.2357 - accuracy: 0.0000e+00
# Epoch 10/100
# 699/699 [==============================] - 1s 1ms/step - loss: -2677.5903 - accuracy: 0.0000e+00
# Epoch 11/100
# 699/699 [==============================] - 1s 1ms/step - loss: -3736.6299 - accuracy: 0.0000e+00
# Epoch 12/100
# 699/699 [==============================] - 1s 1ms/step - loss: -5006.8013 - accuracy: 0.0000e+00
# Epoch 13/100
# 699/699 [==============================] - 1s 1ms/step - loss: -6560.6724 - accuracy: 0.0000e+00
# Epoch 14/100
# 699/699 [==============================] - 1s 1ms/step - loss: -8452.8555 - accuracy: 0.0000e+00
# Epoch 15/100
# 699/699 [==============================] - 1s 1ms/step - loss: -10690.0967 - accuracy: 0.0000e+00
# Epoch 16/100
# 699/699 [==============================] - 1s 1ms/step - loss: -13316.2529 - accuracy: 0.0000e+00
# Epoch 17/100
# 699/699 [==============================] - 1s 1ms/step - loss: -16329.5234 - accuracy: 0.0000e+00
# Epoch 18/100
# 699/699 [==============================] - 1s 1ms/step - loss: -19768.0391 - accuracy: 0.0000e+00
# Epoch 19/100
# 699/699 [==============================] - 1s 1ms/step - loss: -23734.2949 - accuracy: 0.0000e+00
# Epoch 20/100
# 699/699 [==============================] - 1s 1ms/step - loss: -28251.5879 - accuracy: 0.0000e+00
# Epoch 21/100
# 699/699 [==============================] - 1s 1ms/step - loss: -33310.3867 - accuracy: 0.0000e+00
# Epoch 22/100
# 699/699 [==============================] - 1s 1ms/step - loss: -38973.5703 - accuracy: 0.0000e+00
# Epoch 23/100
# 699/699 [==============================] - 1s 1ms/step - loss: -45305.8164 - accuracy: 0.0000e+00
# Epoch 24/100
# 699/699 [==============================] - 1s 1ms/step - loss: -52378.3320 - accuracy: 0.0000e+00
# Epoch 25/100
# 699/699 [==============================] - 1s 1ms/step - loss: -60208.2188 - accuracy: 0.0000e+00
# Epoch 26/100
# 699/699 [==============================] - 1s 1ms/step - loss: -68818.9609 - accuracy: 0.0000e+00
# Epoch 27/100
# 699/699 [==============================] - 1s 1ms/step - loss: -78376.5469 - accuracy: 0.0000e+00
# Epoch 28/100
# 699/699 [==============================] - 1s 1ms/step - loss: -88750.7031 - accuracy: 0.0000e+00
# Epoch 29/100
# 699/699 [==============================] - 1s 1ms/step - loss: -100048.3750 - accuracy: 0.0000e+00
# Epoch 30/100
# 699/699 [==============================] - 1s 1ms/step - loss: -112241.4453 - accuracy: 0.0000e+00
# Epoch 31/100
# 699/699 [==============================] - 1s 1ms/step - loss: -125557.4844 - accuracy: 0.0000e+00
# Epoch 32/100
# 699/699 [==============================] - 1s 1ms/step - loss: -139962.7344 - accuracy: 0.0000e+00
# Epoch 33/100
# 699/699 [==============================] - 1s 1ms/step - loss: -155478.6562 - accuracy: 0.0000e+00
# Epoch 34/100
# 699/699 [==============================] - 1s 1ms/step - loss: -172126.0000 - accuracy: 0.0000e+00
# Epoch 35/100
# 699/699 [==============================] - 1s 1ms/step - loss: -190338.4219 - accuracy: 0.0000e+00
# Epoch 36/100
# 699/699 [==============================] - 1s 1ms/step - loss: -210079.7031 - accuracy: 0.0000e+00
# Epoch 37/100
# 699/699 [==============================] - 1s 1ms/step - loss: -230934.0312 - accuracy: 0.0000e+00
# Epoch 38/100
# 699/699 [==============================] - 1s 1ms/step - loss: -253251.8281 - accuracy: 0.0000e+00
# Epoch 39/100
# 699/699 [==============================] - 1s 1ms/step - loss: -277006.3125 - accuracy: 0.0000e+00
# Epoch 40/100
# 699/699 [==============================] - 1s 1ms/step - loss: -302253.5000 - accuracy: 0.0000e+00
# Epoch 41/100
# 699/699 [==============================] - 1s 1ms/step - loss: -328943.2188 - accuracy: 0.0000e+00
# Epoch 42/100
# 699/699 [==============================] - 1s 1ms/step - loss: -357587.0000 - accuracy: 0.0000e+00
# Epoch 43/100
# 699/699 [==============================] - 1s 1ms/step - loss: -387784.7188 - accuracy: 0.0000e+00
# Epoch 44/100
# 699/699 [==============================] - 1s 1ms/step - loss: -419888.3750 - accuracy: 0.0000e+00
# Epoch 45/100
# 699/699 [==============================] - 1s 1ms/step - loss: -453781.7500 - accuracy: 0.0000e+00
# Epoch 46/100
# 699/699 [==============================] - 1s 1ms/step - loss: -490217.3750 - accuracy: 0.0000e+00
# Epoch 47/100
# 699/699 [==============================] - 1s 1ms/step - loss: -528623.9375 - accuracy: 0.0000e+00
# Epoch 48/100
# 699/699 [==============================] - 1s 1ms/step - loss: -569134.4375 - accuracy: 0.0000e+00
# Epoch 49/100
# 699/699 [==============================] - 1s 1ms/step - loss: -611783.0000 - accuracy: 0.0000e+00
# Epoch 50/100
# 699/699 [==============================] - 1s 1ms/step - loss: -656152.5625 - accuracy: 0.0000e+00
# Epoch 51/100
# 699/699 [==============================] - 1s 1ms/step - loss: -702876.3125 - accuracy: 0.0000e+00
# Epoch 52/100
# 699/699 [==============================] - 1s 1ms/step - loss: -752400.8750 - accuracy: 0.0000e+00
# Epoch 53/100
# 699/699 [==============================] - 1s 1ms/step - loss: -804353.1250 - accuracy: 0.0000e+00
# Epoch 54/100
# 699/699 [==============================] - 1s 1ms/step - loss: -858896.5625 - accuracy: 0.0000e+00
# Epoch 55/100
# 699/699 [==============================] - 1s 1ms/step - loss: -916101.9375 - accuracy: 0.0000e+00
# Epoch 56/100
# 699/699 [==============================] - 1s 1ms/step - loss: -976120.5000 - accuracy: 0.0000e+00
# Epoch 57/100
# 699/699 [==============================] - 1s 1ms/step - loss: -1038753.6250 - accuracy: 0.0000e+00
# Epoch 58/100
# 699/699 [==============================] - 1s 1ms/step - loss: -1104043.3750 - accuracy: 0.0000e+00
# Epoch 59/100
# 699/699 [==============================] - 1s 1ms/step - loss: -1171582.5000 - accuracy: 0.0000e+00
# Epoch 60/100
# 699/699 [==============================] - 1s 1ms/step - loss: -1242623.1250 - accuracy: 0.0000e+00
# Epoch 61/100
# 699/699 [==============================] - 1s 1ms/step - loss: -1316742.8750 - accuracy: 0.0000e+00
# Epoch 62/100
# 699/699 [==============================] - 1s 1ms/step - loss: -1394535.6250 - accuracy: 0.0000e+00
# Epoch 63/100
# 699/699 [==============================] - 1s 1ms/step - loss: -1475141.5000 - accuracy: 0.0000e+00
# Epoch 64/100
# 699/699 [==============================] - 1s 1ms/step - loss: -1559946.7500 - accuracy: 0.0000e+00
# Epoch 65/100
# 699/699 [==============================] - 1s 1ms/step - loss: -1646755.1250 - accuracy: 0.0000e+00
# Epoch 66/100
# 699/699 [==============================] - 1s 1ms/step - loss: -1737754.6250 - accuracy: 0.0000e+00
# Epoch 67/100
# 699/699 [==============================] - 1s 1ms/step - loss: -1832949.8750 - accuracy: 0.0000e+00
# Epoch 68/100
# 699/699 [==============================] - 1s 1ms/step - loss: -1931757.5000 - accuracy: 0.0000e+00
# Epoch 69/100
# 699/699 [==============================] - 1s 1ms/step - loss: -2035175.1250 - accuracy: 0.0000e+00
# Epoch 70/100
# 699/699 [==============================] - 1s 1ms/step - loss: -2141848.7500 - accuracy: 0.0000e+00
# Epoch 71/100
# 699/699 [==============================] - 1s 1ms/step - loss: -2254376.2500 - accuracy: 0.0000e+00
# Epoch 72/100
# 699/699 [==============================] - 1s 1ms/step - loss: -2370311.5000 - accuracy: 0.0000e+00
# Epoch 73/100
# 699/699 [==============================] - 1s 1ms/step - loss: -2490216.7500 - accuracy: 0.0000e+00
# Epoch 74/100
# 699/699 [==============================] - 1s 1ms/step - loss: -2614351.7500 - accuracy: 0.0000e+00
# Epoch 75/100
# 699/699 [==============================] - 1s 1ms/step - loss: -2742367.7500 - accuracy: 0.0000e+00
# Epoch 76/100
# 699/699 [==============================] - 1s 1ms/step - loss: -2874204.2500 - accuracy: 0.0000e+00
# Epoch 77/100
# 699/699 [==============================] - 1s 1ms/step - loss: -3011248.0000 - accuracy: 0.0000e+00
# Epoch 78/100
# 699/699 [==============================] - 1s 1ms/step - loss: -3152845.0000 - accuracy: 0.0000e+00
# Epoch 79/100
# 699/699 [==============================] - 1s 1ms/step - loss: -3299799.7500 - accuracy: 0.0000e+00
# Epoch 80/100
# 699/699 [==============================] - 1s 1ms/step - loss: -3452503.5000 - accuracy: 0.0000e+00
# Epoch 81/100
# 699/699 [==============================] - 1s 1ms/step - loss: -3611191.0000 - accuracy: 0.0000e+00
# Epoch 82/100
# 699/699 [==============================] - 1s 1ms/step - loss: -3773268.5000 - accuracy: 0.0000e+00
# Epoch 83/100
# 699/699 [==============================] - 1s 2ms/step - loss: -3940329.7500 - accuracy: 0.0000e+00
# Epoch 84/100
# 699/699 [==============================] - 1s 1ms/step - loss: -4110985.7500 - accuracy: 0.0000e+00
# Epoch 85/100
# 699/699 [==============================] - 1s 1ms/step - loss: -4287945.0000 - accuracy: 0.0000e+00
# Epoch 86/100
# 699/699 [==============================] - 1s 1ms/step - loss: -4471559.5000 - accuracy: 0.0000e+00
# Epoch 87/100
# 699/699 [==============================] - 1s 1ms/step - loss: -4660792.0000 - accuracy: 0.0000e+00
# Epoch 88/100
# 699/699 [==============================] - 1s 1ms/step - loss: -4856256.5000 - accuracy: 0.0000e+00
# Epoch 89/100
# 699/699 [==============================] - 1s 1ms/step - loss: -5058848.5000 - accuracy: 0.0000e+00
# Epoch 90/100
# 699/699 [==============================] - 1s 1ms/step - loss: -5268432.5000 - accuracy: 0.0000e+00
# Epoch 91/100
# 699/699 [==============================] - 1s 1ms/step - loss: -5480998.0000 - accuracy: 0.0000e+00
# Epoch 92/100
# 699/699 [==============================] - 1s 1ms/step - loss: -5699344.5000 - accuracy: 0.0000e+00
# Epoch 93/100
# 699/699 [==============================] - 1s 1ms/step - loss: -5927416.5000 - accuracy: 0.0000e+00
# Epoch 94/100
# 699/699 [==============================] - 1s 1ms/step - loss: -6162797.0000 - accuracy: 0.0000e+00
# Epoch 95/100
# 699/699 [==============================] - 1s 1ms/step - loss: -6404772.0000 - accuracy: 0.0000e+00
# Epoch 96/100
# 699/699 [==============================] - 1s 1ms/step - loss: -6653777.5000 - accuracy: 0.0000e+00
# Epoch 97/100
# 699/699 [==============================] - 1s 1ms/step - loss: -6908730.0000 - accuracy: 0.0000e+00
# Epoch 98/100
# 699/699 [==============================] - 1s 2ms/step - loss: -7172653.0000 - accuracy: 0.0000e+00
# Epoch 99/100
# 699/699 [==============================] - 1s 1ms/step - loss: -7444648.0000 - accuracy: 0.0000e+00
# Epoch 100/100
# 699/699 [==============================] - 1s 1ms/step - loss: -7725622.0000 - accuracy: 0.0000e+00

# %%
y_pred = ann.predict(X_test)
# Out:
# 15/15 [==============================] - 0s 1ms/step

# %%
# Calculate the MSE (Mean Squared Error)
ANN_mse = mean_squared_error(y_test, y_pred)

# Calculate the RMSE (Root Mean Squared Error)
ANN_rmse = np.sqrt(MLR_mse)

# Calculate the MAE (Mean Absolute Error)
ANN_mae = mean_absolute_error(y_test, y_pred)

# Calculate the R-squared (R²) score
ANN_r2 = r2_score(y_test, y_pred)

# Print the metrics
print("Root Mean Squared Error (RMSE):", ANN_rmse)
print("Mean Absolute Error (MAE):", ANN_mae)
print("R-squared (R²):", ANN_r2)
# Out:
# Root Mean Squared Error (RMSE): 0.8940075912139515
# Mean Absolute Error (MAE): 0.8112536008103742
# R-squared (R²): 0.03957189442208642

# %% [markdown]
# ##XGBOOST

# %%
from xgboost import XGBRegressor  # For classification tasks, use XGBClassifier

# Create an XGBoost model
xgb_regressor = XGBRegressor()  # For classification, use XGBClassifier

# Define the parameter grid
param_grid = {
    'n_estimators': [100, 200, 300],  # Number of boosting rounds (trees)
    'learning_rate': [0.01, 0.1, 0.2],  # Step size shrinkage to prevent overfitting
    'max_depth': [3, 4, 5],  # Maximum depth of each tree
    'min_child_weight': [1, 2, 3]  # Minimum sum of instance weight (hessian) needed in a child
}

# Create the GridSearchCV object
grid_search = GridSearchCV(xgb_regressor, param_grid, cv=5)  # cv is the number of cross-validation folds

# Fit the model to the data
grid_search.fit(X_train, y_train)  # X_train and y_train are your training data

# Print the best hyperparameters
best_params = grid_search.best_params_
print("Best Hyperparameters:", best_params)

# Get the best estimator
best_model = grid_search.best_estimator_

# You can use best_model for predictions
# Out:
# Best Hyperparameters: {'learning_rate': 0.01, 'max_depth': 3, 'min_child_weight': 3, 'n_estimators': 300}

# %%
y_pred = best_model.predict(X_test)

# %%
# Calculate the MSE (Mean Squared Error)
XGB_mse = mean_squared_error(y_test, y_pred)

# Calculate the RMSE (Root Mean Squared Error)
XGB_rmse = np.sqrt(MLR_mse)

# Calculate the MAE (Mean Absolute Error)
XGB_mae = mean_absolute_error(y_test, y_pred)

# Calculate the R-squared (R²) score
XGB_r2 = r2_score(y_test, y_pred)

# Print the metrics
print("Root Mean Squared Error (RMSE):", XGB_rmse)
print("Mean Absolute Error (MAE):", XGB_mae)
print("R-squared (R²):", XGB_r2)
# Out:
# Root Mean Squared Error (RMSE): 0.8940075912139515
# Mean Absolute Error (MAE): 0.7027252428395259
# R-squared (R²): 0.22885117986944892

# %% [markdown]
# ##Catboost

# %%
# !pip install catboost
# Out:
# Collecting catboost
#   Downloading catboost-1.2.2-cp310-cp310-manylinux2014_x86_64.whl (98.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.7/98.7 MB 8.9 MB/s eta 0:00:00
# Requirement already satisfied: graphviz in /usr/local/lib/python3.10/dist-packages (from catboost) (0.20.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from catboost) (3.7.1)
# Requirement already satisfied: numpy>=1.16.0 in /usr/local/lib/python3.10/dist-packages (from catboost) (1.23.5)
# Requirement already satisfied: pandas>=0.24 in /usr/local/lib/python3.10/dist-packages (from catboost) (1.5.3)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from catboost) (1.11.3)
# Requirement already satisfied: plotly in /usr/local/lib/python3.10/dist-packages (from catboost) (5.15.0)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from catboost) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2023.3.post1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (4.43.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (3.1.1)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly->catboost) (8.2.3)
# Installing collected packages: catboost
# Successfully installed catboost-1.2.2

# %%
from catboost import CatBoostRegressor

# Define your parameter grid for hyperparameter tuning
param_grid = {
    'iterations': [100, 200, 300],  # Number of boosting rounds (trees)
    'depth': [6, 8, 10],  # Maximum depth of each tree
    'learning_rate': [0.01, 0.1, 0.2],  # Step size shrinkage to prevent overfitting
    'l2_leaf_reg': [3, 5, 7]  # L2 regularization coefficient
}

# Create a CatBoost regressor
catboost_regressor = CatBoostRegressor()

# Create the GridSearchCV object
grid_search = GridSearchCV(catboost_regressor, param_grid, cv=5, verbose=1, n_jobs=-1)  # cv is the number of cross-validation folds

# Fit the model to the data
grid_search.fit(X_train, y_train)  # X_train and y_train are your training data

# Print the best hyperparameters
best_params = grid_search.best_params_
print("Best Hyperparameters:", best_params)

# Get the best estimator (best model)
best_model = grid_search.best_estimator_

# You can use best_model for predictions
# Out:
# Fitting 5 folds for each of 81 candidates, totalling 405 fits
# 0:	learn: 0.9979691	total: 52.1ms	remaining: 15.6s
# 1:	learn: 0.9959153	total: 56ms	remaining: 8.35s
# 2:	learn: 0.9938255	total: 60ms	remaining: 5.94s
# 3:	learn: 0.9919062	total: 63.9ms	remaining: 4.73s
# 4:	learn: 0.9898859	total: 67.9ms	remaining: 4s
# 5:	learn: 0.9878997	total: 71.9ms	remaining: 3.52s
# 6:	learn: 0.9859993	total: 75.8ms	remaining: 3.17s
# 7:	learn: 0.9840646	total: 79.6ms	remaining: 2.91s
# 8:	learn: 0.9822568	total: 83.2ms	remaining: 2.69s
# 9:	learn: 0.9805155	total: 87.2ms	remaining: 2.53s
# 10:	learn: 0.9784763	total: 91.1ms	remaining: 2.39s
# 11:	learn: 0.9768311	total: 92.5ms	remaining: 2.22s
# 12:	learn: 0.9752325	total: 96.4ms	remaining: 2.13s
# 13:	learn: 0.9735927	total: 96.9ms	remaining: 1.98s
# 14:	learn: 0.9718096	total: 101ms	remaining: 1.92s
# 15:	learn: 0.9701214	total: 105ms	remaining: 1.86s
# 16:	learn: 0.9685235	total: 109ms	remaining: 1.81s
# 17:	learn: 0.9669230	total: 113ms	remaining: 1.77s
# 18:	learn: 0.9652886	total: 117ms	remaining: 1.73s
# 19:	learn: 0.9636212	total: 121ms	remaining: 1.69s
# 20:	learn: 0.9621327	total: 125ms	remaining: 1.66s
# 21:	learn: 0.9605392	total: 129ms	remaining: 1.63s
# 22:	learn: 0.9588381	total: 133ms	remaining: 1.6s
# 23:	learn: 0.9572488	total: 139ms	remaining: 1.6s
# 24:	learn: 0.9556718	total: 143ms	remaining: 1.58s
# 25:	learn: 0.9542112	total: 147ms	remaining: 1.55s
# 26:	learn: 0.9527191	total: 151ms	remaining: 1.53s
# 27:	learn: 0.9513124	total: 155ms	remaining: 1.51s
# 28:	learn: 0.9499029	total: 159ms	remaining: 1.49s
# 29:	learn: 0.9485195	total: 163ms	remaining: 1.47s
# 30:	learn: 0.9471115	total: 167ms	remaining: 1.45s
# 31:	learn: 0.9458788	total: 171ms	remaining: 1.43s
# 32:	learn: 0.9446624	total: 175ms	remaining: 1.42s
# 33:	learn: 0.9433677	total: 179ms	remaining: 1.4s
# 34:	learn: 0.9420601	total: 183ms	remaining: 1.38s
# 35:	learn: 0.9408189	total: 188ms	remaining: 1.38s
# 36:	learn: 0.9395205	total: 192ms	remaining: 1.36s
# 37:	learn: 0.9382850	total: 196ms	remaining: 1.35s
# 38:	learn: 0.9370327	total: 200ms	remaining: 1.33s
# 39:	learn: 0.9356988	total: 203ms	remaining: 1.32s
# 40:	learn: 0.9345702	total: 207ms	remaining: 1.31s
# 41:	learn: 0.9334061	total: 211ms	remaining: 1.29s
# 42:	learn: 0.9322441	total: 215ms	remaining: 1.28s
# 43:	learn: 0.9310427	total: 218ms	remaining: 1.27s
# 44:	learn: 0.9300488	total: 222ms	remaining: 1.26s
# 45:	learn: 0.9289954	total: 226ms	remaining: 1.25s
# 46:	learn: 0.9278759	total: 231ms	remaining: 1.25s
# 47:	learn: 0.9267956	total: 235ms	remaining: 1.24s
# 48:	learn: 0.9257217	total: 239ms	remaining: 1.23s
# 49:	learn: 0.9246160	total: 243ms	remaining: 1.22s
# 50:	learn: 0.9234968	total: 249ms	remaining: 1.22s
# 51:	learn: 0.9224153	total: 254ms	remaining: 1.21s
# 52:	learn: 0.9213136	total: 258ms	remaining: 1.2s
# 53:	learn: 0.9202962	total: 262ms	remaining: 1.19s
# 54:	learn: 0.9192724	total: 265ms	remaining: 1.18s
# 55:	learn: 0.9182965	total: 270ms	remaining: 1.18s
# 56:	learn: 0.9173591	total: 275ms	remaining: 1.17s
# 57:	learn: 0.9164881	total: 277ms	remaining: 1.15s
# 58:	learn: 0.9154791	total: 280ms	remaining: 1.14s
# 59:	learn: 0.9144762	total: 284ms	remaining: 1.13s
# 60:	learn: 0.9135871	total: 287ms	remaining: 1.13s
# 61:	learn: 0.9126695	total: 291ms	remaining: 1.12s
# 62:	learn: 0.9117864	total: 295ms	remaining: 1.11s
# 63:	learn: 0.9108594	total: 298ms	remaining: 1.1s
# 64:	learn: 0.9099007	total: 302ms	remaining: 1.09s
# 65:	learn: 0.9090477	total: 306ms	remaining: 1.09s
# 66:	learn: 0.9082023	total: 310ms	remaining: 1.08s
# 67:	learn: 0.9073883	total: 314ms	remaining: 1.07s
# 68:	learn: 0.9066017	total: 317ms	remaining: 1.06s
# 69:	learn: 0.9058082	total: 321ms	remaining: 1.05s
# 70:	learn: 0.9049717	total: 325ms	remaining: 1.05s
# 71:	learn: 0.9041716	total: 329ms	remaining: 1.04s
# 72:	learn: 0.9035499	total: 333ms	remaining: 1.03s
# 73:	learn: 0.9028178	total: 337ms	remaining: 1.03s
# 74:	learn: 0.9020974	total: 341ms	remaining: 1.02s
# 75:	learn: 0.9014821	total: 345ms	remaining: 1.01s
# 76:	learn: 0.9006709	total: 349ms	remaining: 1.01s
# 77:	learn: 0.8998926	total: 352ms	remaining: 1s
# 78:	learn: 0.8992046	total: 356ms	remaining: 997ms
# 79:	learn: 0.8985862	total: 358ms	remaining: 984ms
# 80:	learn: 0.8978044	total: 361ms	remaining: 977ms
# 81:	learn: 0.8970490	total: 365ms	remaining: 971ms
# 82:	learn: 0.8963282	total: 369ms	remaining: 965ms
# 83:	learn: 0.8955782	total: 373ms	remaining: 959ms
# 84:	learn: 0.8948555	total: 377ms	remaining: 953ms
# 85:	learn: 0.8941286	total: 381ms	remaining: 948ms
# 86:	learn: 0.8934353	total: 385ms	remaining: 942ms
# 87:	learn: 0.8927869	total: 389ms	remaining: 937ms
# 88:	learn: 0.8921062	total: 393ms	remaining: 931ms
# 89:	learn: 0.8915276	total: 397ms	remaining: 926ms
# 90:	learn: 0.8909659	total: 400ms	remaining: 920ms
# 91:	learn: 0.8903790	total: 405ms	remaining: 915ms
# 92:	learn: 0.8898637	total: 411ms	remaining: 914ms
# 93:	learn: 0.8892682	total: 415ms	remaining: 909ms
# 94:	learn: 0.8886885	total: 418ms	remaining: 903ms
# 95:	learn: 0.8880274	total: 422ms	remaining: 897ms
# 96:	learn: 0.8874933	total: 426ms	remaining: 892ms
# 97:	learn: 0.8869413	total: 430ms	remaining: 886ms
# 98:	learn: 0.8863323	total: 434ms	remaining: 880ms
# 99:	learn: 0.8858271	total: 437ms	remaining: 875ms
# 100:	learn: 0.8853536	total: 441ms	remaining: 869ms
# 101:	learn: 0.8848545	total: 448ms	remaining: 870ms
# 102:	learn: 0.8842384	total: 452ms	remaining: 865ms
# 103:	learn: 0.8837309	total: 456ms	remaining: 859ms
# 104:	learn: 0.8832268	total: 460ms	remaining: 854ms
# 105:	learn: 0.8826556	total: 465ms	remaining: 851ms
# 106:	learn: 0.8821104	total: 469ms	remaining: 846ms
# 107:	learn: 0.8815469	total: 473ms	remaining: 840ms
# 108:	learn: 0.8809595	total: 476ms	remaining: 835ms
# 109:	learn: 0.8804060	total: 480ms	remaining: 830ms
# 110:	learn: 0.8799694	total: 484ms	remaining: 824ms
# 111:	learn: 0.8794532	total: 488ms	remaining: 819ms
# 112:	learn: 0.8789916	total: 492ms	remaining: 814ms
# 113:	learn: 0.8785485	total: 495ms	remaining: 808ms
# 114:	learn: 0.8780548	total: 499ms	remaining: 803ms
# 115:	learn: 0.8775092	total: 503ms	remaining: 798ms
# 116:	learn: 0.8770689	total: 511ms	remaining: 799ms
# 117:	learn: 0.8766306	total: 515ms	remaining: 794ms
# 118:	learn: 0.8762046	total: 519ms	remaining: 789ms
# 119:	learn: 0.8757515	total: 522ms	remaining: 784ms
# 120:	learn: 0.8753344	total: 526ms	remaining: 778ms
# 121:	learn: 0.8749861	total: 530ms	remaining: 773ms
# 122:	learn: 0.8744815	total: 534ms	remaining: 768ms
# 123:	learn: 0.8740103	total: 537ms	remaining: 763ms
# 124:	learn: 0.8735435	total: 541ms	remaining: 758ms
# 125:	learn: 0.8730777	total: 545ms	remaining: 753ms
# 126:	learn: 0.8726905	total: 549ms	remaining: 748ms
# 127:	learn: 0.8722981	total: 553ms	remaining: 743ms
# 128:	learn: 0.8719651	total: 556ms	remaining: 737ms
# 129:	learn: 0.8715685	total: 560ms	remaining: 732ms
# 130:	learn: 0.8711646	total: 564ms	remaining: 727ms
# 131:	learn: 0.8708135	total: 568ms	remaining: 723ms
# 132:	learn: 0.8704608	total: 572ms	remaining: 718ms
# 133:	learn: 0.8700632	total: 576ms	remaining: 713ms
# 134:	learn: 0.8697528	total: 579ms	remaining: 708ms
# 135:	learn: 0.8693873	total: 583ms	remaining: 703ms
# 136:	learn: 0.8690611	total: 587ms	remaining: 699ms
# 137:	learn: 0.8686952	total: 591ms	remaining: 694ms
# 138:	learn: 0.8683015	total: 594ms	remaining: 689ms
# 139:	learn: 0.8679075	total: 598ms	remaining: 684ms
# 140:	learn: 0.8675757	total: 602ms	remaining: 679ms
# 141:	learn: 0.8672593	total: 606ms	remaining: 674ms
# 142:	learn: 0.8669525	total: 610ms	remaining: 669ms
# 143:	learn: 0.8665983	total: 613ms	remaining: 664ms
# 144:	learn: 0.8661314	total: 617ms	remaining: 660ms
# 145:	learn: 0.8656828	total: 623ms	remaining: 657ms
# 146:	learn: 0.8652901	total: 628ms	remaining: 653ms
# 147:	learn: 0.8649715	total: 631ms	remaining: 648ms
# 148:	learn: 0.8648010	total: 632ms	remaining: 641ms
# 149:	learn: 0.8644360	total: 636ms	remaining: 636ms
# 150:	learn: 0.8640956	total: 640ms	remaining: 631ms
# 151:	learn: 0.8637828	total: 642ms	remaining: 625ms
# 152:	learn: 0.8634330	total: 648ms	remaining: 623ms
# 153:	learn: 0.8631762	total: 653ms	remaining: 619ms
# 154:	learn: 0.8628604	total: 657ms	remaining: 614ms
# 155:	learn: 0.8625684	total: 661ms	remaining: 610ms
# 156:	learn: 0.8622567	total: 664ms	remaining: 605ms
# 157:	learn: 0.8620193	total: 668ms	remaining: 601ms
# 158:	learn: 0.8617357	total: 672ms	remaining: 596ms
# 159:	learn: 0.8614998	total: 676ms	remaining: 591ms
# 160:	learn: 0.8612417	total: 679ms	remaining: 586ms
# 161:	learn: 0.8609539	total: 683ms	remaining: 582ms
# 162:	learn: 0.8606975	total: 687ms	remaining: 577ms
# 163:	learn: 0.8603942	total: 691ms	remaining: 573ms
# 164:	learn: 0.8600425	total: 694ms	remaining: 568ms
# 165:	learn: 0.8597788	total: 698ms	remaining: 564ms
# 166:	learn: 0.8595232	total: 702ms	remaining: 559ms
# 167:	learn: 0.8593279	total: 706ms	remaining: 555ms
# 168:	learn: 0.8590515	total: 710ms	remaining: 550ms
# 169:	learn: 0.8588532	total: 714ms	remaining: 546ms
# 170:	learn: 0.8586103	total: 717ms	remaining: 541ms
# 171:	learn: 0.8583742	total: 724ms	remaining: 539ms
# 172:	learn: 0.8581211	total: 732ms	remaining: 537ms
# 173:	learn: 0.8579145	total: 736ms	remaining: 533ms
# 174:	learn: 0.8576793	total: 740ms	remaining: 528ms
# 175:	learn: 0.8574912	total: 743ms	remaining: 524ms
# 176:	learn: 0.8572037	total: 747ms	remaining: 519ms
# 177:	learn: 0.8569391	total: 751ms	remaining: 515ms
# 178:	learn: 0.8566945	total: 755ms	remaining: 510ms
# 179:	learn: 0.8564750	total: 759ms	remaining: 506ms
# 180:	learn: 0.8561839	total: 763ms	remaining: 501ms
# 181:	learn: 0.8559058	total: 767ms	remaining: 497ms
# 182:	learn: 0.8556460	total: 770ms	remaining: 493ms
# 183:	learn: 0.8554449	total: 774ms	remaining: 488ms
# 184:	learn: 0.8552099	total: 778ms	remaining: 484ms
# 185:	learn: 0.8549593	total: 782ms	remaining: 479ms
# 186:	learn: 0.8546546	total: 787ms	remaining: 476ms
# 187:	learn: 0.8544405	total: 791ms	remaining: 471ms
# 188:	learn: 0.8542284	total: 795ms	remaining: 467ms
# 189:	learn: 0.8539898	total: 799ms	remaining: 463ms
# 190:	learn: 0.8537630	total: 803ms	remaining: 458ms
# 191:	learn: 0.8535631	total: 806ms	remaining: 454ms
# 192:	learn: 0.8533484	total: 810ms	remaining: 449ms
# 193:	learn: 0.8531530	total: 816ms	remaining: 446ms
# 194:	learn: 0.8529139	total: 820ms	remaining: 442ms
# 195:	learn: 0.8526879	total: 824ms	remaining: 437ms
# 196:	learn: 0.8525149	total: 828ms	remaining: 433ms
# 197:	learn: 0.8522552	total: 832ms	remaining: 428ms
# 198:	learn: 0.8520703	total: 835ms	remaining: 424ms
# 199:	learn: 0.8518721	total: 839ms	remaining: 420ms
# 200:	learn: 0.8516493	total: 843ms	remaining: 415ms
# 201:	learn: 0.8514561	total: 850ms	remaining: 412ms
# 202:	learn: 0.8513053	total: 857ms	remaining: 409ms
# 203:	learn: 0.8511579	total: 862ms	remaining: 406ms
# 204:	learn: 0.8509909	total: 867ms	remaining: 402ms
# 205:	learn: 0.8507903	total: 871ms	remaining: 398ms
# 206:	learn: 0.8505867	total: 875ms	remaining: 393ms
# 207:	learn: 0.8504143	total: 879ms	remaining: 389ms
# 208:	learn: 0.8501766	total: 883ms	remaining: 384ms
# 209:	learn: 0.8499849	total: 886ms	remaining: 380ms
# 210:	learn: 0.8497991	total: 890ms	remaining: 375ms
# 211:	learn: 0.8496043	total: 894ms	remaining: 371ms
# 212:	learn: 0.8494730	total: 897ms	remaining: 366ms
# 213:	learn: 0.8492918	total: 901ms	remaining: 362ms
# 214:	learn: 0.8490663	total: 904ms	remaining: 358ms
# 215:	learn: 0.8488323	total: 908ms	remaining: 353ms
# 216:	learn: 0.8486561	total: 912ms	remaining: 349ms
# 217:	learn: 0.8484828	total: 916ms	remaining: 344ms
# 218:	learn: 0.8483403	total: 919ms	remaining: 340ms
# 219:	learn: 0.8481759	total: 923ms	remaining: 336ms
# 220:	learn: 0.8481074	total: 924ms	remaining: 330ms
# 221:	learn: 0.8479699	total: 928ms	remaining: 326ms
# 222:	learn: 0.8477626	total: 932ms	remaining: 322ms
# 223:	learn: 0.8475464	total: 935ms	remaining: 317ms
# 224:	learn: 0.8473952	total: 939ms	remaining: 313ms
# 225:	learn: 0.8472491	total: 943ms	remaining: 309ms
# 226:	learn: 0.8471025	total: 947ms	remaining: 304ms
# 227:	learn: 0.8469114	total: 950ms	remaining: 300ms
# 228:	learn: 0.8467681	total: 954ms	remaining: 296ms
# 229:	learn: 0.8465989	total: 958ms	remaining: 291ms
# 230:	learn: 0.8464952	total: 961ms	remaining: 287ms
# 231:	learn: 0.8463890	total: 965ms	remaining: 283ms
# 232:	learn: 0.8462413	total: 969ms	remaining: 279ms
# 233:	learn: 0.8460795	total: 971ms	remaining: 274ms
# 234:	learn: 0.8458955	total: 974ms	remaining: 269ms
# 235:	learn: 0.8457463	total: 978ms	remaining: 265ms
# 236:	learn: 0.8456321	total: 982ms	remaining: 261ms
# 237:	learn: 0.8455017	total: 985ms	remaining: 257ms
# 238:	learn: 0.8453543	total: 989ms	remaining: 252ms
# 239:	learn: 0.8452193	total: 993ms	remaining: 248ms
# 240:	learn: 0.8450813	total: 996ms	remaining: 244ms
# 241:	learn: 0.8449702	total: 998ms	remaining: 239ms
# 242:	learn: 0.8448423	total: 1s	remaining: 235ms
# 243:	learn: 0.8446434	total: 1s	remaining: 231ms
# 244:	learn: 0.8445218	total: 1.01s	remaining: 226ms
# 245:	learn: 0.8443795	total: 1.01s	remaining: 222ms
# 246:	learn: 0.8443064	total: 1.01s	remaining: 217ms
# 247:	learn: 0.8442031	total: 1.02s	remaining: 213ms
# 248:	learn: 0.8440837	total: 1.02s	remaining: 209ms
# 249:	learn: 0.8439209	total: 1.02s	remaining: 205ms
# 250:	learn: 0.8437796	total: 1.03s	remaining: 201ms
# 251:	learn: 0.8436904	total: 1.03s	remaining: 197ms
# 252:	learn: 0.8435107	total: 1.03s	remaining: 192ms
# 253:	learn: 0.8433096	total: 1.04s	remaining: 188ms
# 254:	learn: 0.8431412	total: 1.04s	remaining: 184ms
# 255:	learn: 0.8429977	total: 1.05s	remaining: 180ms
# 256:	learn: 0.8428469	total: 1.05s	remaining: 176ms
# 257:	learn: 0.8426785	total: 1.06s	remaining: 172ms
# 258:	learn: 0.8425344	total: 1.06s	remaining: 168ms
# 259:	learn: 0.8423963	total: 1.06s	remaining: 164ms
# 260:	learn: 0.8422753	total: 1.07s	remaining: 160ms
# 261:	learn: 0.8421615	total: 1.07s	remaining: 155ms
# 262:	learn: 0.8420066	total: 1.07s	remaining: 151ms
# 263:	learn: 0.8418637	total: 1.08s	remaining: 147ms
# 264:	learn: 0.8416798	total: 1.08s	remaining: 143ms
# 265:	learn: 0.8415369	total: 1.09s	remaining: 140ms
# 266:	learn: 0.8413936	total: 1.1s	remaining: 136ms
# 267:	learn: 0.8412276	total: 1.1s	remaining: 132ms
# 268:	learn: 0.8411209	total: 1.1s	remaining: 127ms
# 269:	learn: 0.8410052	total: 1.11s	remaining: 123ms
# 270:	learn: 0.8409139	total: 1.11s	remaining: 119ms
# 271:	learn: 0.8407938	total: 1.12s	remaining: 115ms
# 272:	learn: 0.8406773	total: 1.12s	remaining: 111ms
# 273:	learn: 0.8405165	total: 1.13s	remaining: 107ms
# 274:	learn: 0.8403872	total: 1.13s	remaining: 103ms
# 275:	learn: 0.8402293	total: 1.13s	remaining: 98.6ms
# 276:	learn: 0.8400937	total: 1.14s	remaining: 94.5ms
# 277:	learn: 0.8398772	total: 1.14s	remaining: 90.6ms
# 278:	learn: 0.8396732	total: 1.15s	remaining: 86.8ms
# 279:	learn: 0.8396396	total: 1.15s	remaining: 82.4ms
# 280:	learn: 0.8395108	total: 1.16s	remaining: 78.3ms
# 281:	learn: 0.8393690	total: 1.16s	remaining: 74.2ms
# 282:	learn: 0.8392203	total: 1.17s	remaining: 70.3ms
# 283:	learn: 0.8390543	total: 1.18s	remaining: 66.5ms
# 284:	learn: 0.8389552	total: 1.19s	remaining: 62.6ms
# 285:	learn: 0.8388232	total: 1.2s	remaining: 58.7ms
# 286:	learn: 0.8387331	total: 1.21s	remaining: 54.7ms
# 287:	learn: 0.8385922	total: 1.22s	remaining: 50.7ms
# 288:	learn: 0.8385309	total: 1.23s	remaining: 46.7ms
# 289:	learn: 0.8383859	total: 1.24s	remaining: 42.6ms
# 290:	learn: 0.8382459	total: 1.25s	remaining: 38.7ms
# 291:	learn: 0.8381099	total: 1.25s	remaining: 34.4ms
# 292:	learn: 0.8379932	total: 1.26s	remaining: 30.1ms
# 293:	learn: 0.8379324	total: 1.27s	remaining: 25.9ms
# 294:	learn: 0.8377961	total: 1.28s	remaining: 21.7ms
# 295:	learn: 0.8376936	total: 1.29s	remaining: 17.4ms
# 296:	learn: 0.8375684	total: 1.29s	remaining: 13.1ms
# 297:	learn: 0.8373929	total: 1.3s	remaining: 8.74ms
# 298:	learn: 0.8372784	total: 1.31s	remaining: 4.39ms
# 299:	learn: 0.8371487	total: 1.32s	remaining: 0us
# Best Hyperparameters: {'depth': 10, 'iterations': 300, 'l2_leaf_reg': 7, 'learning_rate': 0.01}

# %%
y_pred = best_model.predict(X_test)

# Calculate the MSE (Mean Squared Error)
CB_mse = mean_squared_error(y_test, y_pred)

# Calculate the RMSE (Root Mean Squared Error)
CB_rmse = np.sqrt(MLR_mse)

# Calculate the MAE (Mean Absolute Error)
CB_mae = mean_absolute_error(y_test, y_pred)

# Calculate the R-squared (R²) score
CB_r2 = r2_score(y_test, y_pred)

# Print the metrics
print("Root Mean Squared Error (RMSE):", CB_rmse)
print("Mean Absolute Error (MAE):", CB_mae)
print("R-squared (R²):", CB_r2)
# Out:
# Root Mean Squared Error (RMSE): 0.8940075912139515
# Mean Absolute Error (MAE): 0.7057090659083248
# R-squared (R²): 0.22480097988223413

# %% [markdown]
# #Comparing the metrics

# %%
# Define your model names and their corresponding RMSE, MAE, and R² values
models = ["MLR", "PR", "SVR", "DT", "RFR", "ANN", "XGB", "CB"]
rmse_values = [MLR_rmse, PR_rmse, SVR_rmse, DT_rmse, RFR_rmse, ANN_rmse, XGB_rmse, CB_rmse]
mae_values = [MLR_mae, PR_mae, SVR_mae, DT_mae, RFR_mae, ANN_mae, XGB_mae, CB_mae]
r2_values = [MLR_r2, PR_r2, SVR_r2, DT_r2, RFR_r2, ANN_r2, XGB_r2, CB_r2]

# Create a DataFrame to display the results
results_df = pd.DataFrame({
    "Model": models,
    "RMSE": rmse_values,
    "MAE": mae_values,
    "R²": r2_values
})

# Print the DataFrame
print(results_df)
# Out:
#   Model      RMSE       MAE        R²
# 0   MLR  0.894008  0.736022  0.188901
# 1    PR  0.894008  0.707642  0.221825
# 2   SVR  0.894008  0.698071  0.225150
# 3    DT  0.894008  0.709936  0.193488
# 4   RFR  0.894008  0.709253  0.191220
# 5   ANN  0.894008  0.811254  0.039572
# 6   XGB  0.894008  0.702725  0.228851
# 7    CB  0.894008  0.705709  0.224801

# %% [markdown]
# ### So the best model is SVR for this dataset, based on low RMSE and MAE values
